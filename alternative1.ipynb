# %%
import pandas as pd
import tensorflow
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("./House_Rent_Dataset.csv")

size = df[["Size"]].loc[df["Rent"] < 20000]
rent = df["Rent"].loc[df["Rent"] < 20000]
plt.scatter(size,rent)
plt.xlabel("Size")
plt.ylabel("Rent")
plt.show()

df = df.loc[df["Rent"] < 20000]

size = df[["Size"]].loc[df["Rent"] < 20000]
rent = df["Rent"].loc[df["Rent"] < 20000]

plt.scatter(size,rent)
plt.xlabel("Size")
plt.ylabel("Rent")
plt.show()

from sklearn.model_selection import train_test_split

X = df[["Size"]]
y = df["Rent"]

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train,y_train)

model.score(X_test,y_test)

model.score(X_train,y_train)

model.predict([[1200]])

model.predict([[1500]])

model.predict([[2000]])

model.predict([[2500]])

model.predict([[3000]])

model.predict([[3500]])

model.predict([[4000]])

model.predict([[4500]])

model.predict([[5000]])

model.predict([[5500]])

model.predict([[6000]])

model.predict([[6500]])

model.predict([[7000]])

model.predict([[7500]])

model.predict([[8000]])

model.predict([[8500]])

model.predict([[9000]])

model.predict([[9500]])

model.predict([[10000]])

model.predict([[10500]])

model.predict([[11000]])

model.predict([[11500]])

model.predict([[12000]])

model.predict([[12500]])

model.predict([[13000]])

model.predict([[13500]])

model.predict([[14000]])

model.predict([[14500]])

model.predict([[15000]])

model.predict([[15500]])

model.predict([[16000]])

model.predict([[16500]])

model.predict([[17000]])

model.predict([[17500]])

model.predict([[18000]])

model.predict([[18500]])

model.predict([[19000]])

model.predict([[19500]])

model.predict([[20000]])

model.predict([[20500]])

model.predict([[21000]])

model.predict([[21500]])

model.predict([[22000]])

model.predict([[22500]])

model.predict([[23000]])

model.predict([[23500]])

model.predict([[24000]])

model.predict([[24500]])

model.predict([[25000]])

model.predict([[25500]])

model.predict([[26000]])

model.predict([[26500]])

model.predict([[27000]])

model.predict([[27500]])

model.predict([[28000]])

model.predict([[28500]])

model.predict([[29000]])

model
features = df[["Size"]].loc[df["Rent"] < 20000]
target = df["Rent"].loc[df["Rent"] < 20000]
target = np.array(target)
target[0]
features = np.array(features)
features.shape
min,max = features.min(),features.max()
features = features-features/(max-min)
features[0]
model = tensorflow.keras.Sequential([
    tensorflow.keras.layers.Dense(32,input_shape = (1,)),
    tensorflow.keras.layers.Dense(16,activation= 'relu'),
    tensorflow.keras.layers.Dense(1,activation= 'relu'),
])
model.compile(loss ="mae",optimizer=tensorflow.keras.optimizers.Adam())
model.fit(features,target,batch_size=64,shuffle=True,verbose=1,epochs=10,validation_split=0.2)
import random
random_num = random.randint(0,2731)
prediction = model(np.array([features[random_num]]))
print(f"True val: {target[random_num]} Predicted: {prediction[0][0]}")
# Out:
# c:\Users\prath\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\prath\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\prath\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\prath\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...
